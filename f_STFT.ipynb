# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib import mlab
from mpl_toolkits.mplot3d import Axes3D

import numpy as np

from scipy import signal, stats
from scipy.io import loadmat
from scipy.signal import hilbert
from scipy.signal import lfilter
from scipy.interpolate import interp1d

# %%
import z_dependancy as z_dep

# %% [markdown]
# %matplotlib

# %%
# %matplotlib inline

# %%
plt.rc('font', size=20)

# %% [markdown]
# ## Data Generation

# %%
fs = 1024
T = 10
t = np.arange(1/fs,T+1/fs,1/fs)
y=signal.chirp(t,0,1,5,method='quadratic')

plt.figure(figsize=(8,6))
plt.plot(t,y);plt.xlabel('Time(s)'); plt.ylabel('y')

plt.figure(figsize=(8,6))
plt.plot(t,y);plt.xlabel('Time(s)'); plt.ylabel('y')
plt.xlim([0, 2])
# Out:
# (0.0, 2.0)

# %% [markdown]
# ## 주파수 분석

# %%
[f, A] = z_dep.z_fft_simple(y, fs);

# %%
plt.figure(figsize=(8,6))
plt.plot(f,A);plt.xlabel('Freq');plt.ylabel('A')
# Out:
# Text(0, 0.5, 'A')

# %% [markdown]
# ## Waterfall (Time)

# %%
n_div = 20

# %%
y_div = y.reshape(-1, n_div,  order="F")
print(y_div.shape)
# Out:
# (512, 20)

# %%
y_div_len = np.size(y_div,0)

# %%
plot_x=np.tile(t[:y_div_len],[n_div,1]).T
plot_y=np.tile(np.arange(1,n_div+1,1),[y_div_len,1])

# %%
colors = cm.rainbow(np.linspace(0, 1, len(plot_y)))

fig = plt.figure(figsize=(12,8))
ax = Axes3D(fig,azim=-0.001,elev=85)
plt.ylabel('Time (s)');plt.xlabel('Div #')
for x, y, z, c in zip(plot_x.T, plot_y.T, y_div.T, colors):
    ax.plot3D(y,x,z,color=c, linewidth=0.7)
plt.gca().invert_xaxis()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_18068/4061959707.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig,azim=-0.001,elev=85)

# %% [markdown]
# ## Waterfall (Freq)

# %%
A_div=np.empty((0,int((y_div.shape[0])/2+1)),int)
for n in range(n_div):
    f, A = z_dep.z_fft_simple(y_div[:,n]-np.mean(y_div[:,n]),fs)
    A_div = np.append(A_div, np.array([A]), axis=0)
A_div=A_div.T

print(A_div.shape)
# Out:
# (257, 20)

# %%
plt.figure(figsize=(8,6))
plt.stem(f, A_div[:,0]);plt.xlabel('Freq');plt.ylabel('A')
plt.xlim([0,512])

plt.figure(figsize=(8,6))
plt.stem(f, A_div[:,-1]);plt.xlabel('Freq');plt.ylabel('A')
plt.xlim([0,512])
# Out:
# (0.0, 512.0)

# %%
y_div_len = np.size(A_div,0);

plot_x=np.tile(f,[n_div,1]).T
plot_y=np.tile(np.arange(1,n_div+1,1),[y_div_len,1])

# %%
fig = plt.figure(figsize=(12,8))
ax = Axes3D(fig,azim=-0.001,elev=80)
plt.ylabel('Frequency');plt.xlabel('Div #')
for x, y, z, c in zip(plot_x.T, plot_y.T, A_div.T, colors):
    ax.plot3D(y,x,z,color=c, linewidth=0.5)
plt.gca().invert_xaxis()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp/ipykernel_18068/2373743295.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig,azim=-0.001,elev=80)

# %% [markdown]
# # Short Time Fourier Transform

# %%
fs = 1024
T = 1
t = np.arange(1/fs,T+1/fs,1/fs)
y=signal.chirp(t,0,1,150,method='quadratic')

plt.figure(figsize=(8,6))
plt.plot(t,y);plt.xlabel('Time(s)'); plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### First Example

# %%
n_win_numb=256;
n_win = np.hamming(n_win_numb);
n_overlap = 0;
nfft = n_win_numb;

print('7 Time Segments')
plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Comparison: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# 7 Time Segments
# Text(0, 0.5, 'freq(Hz)')

# %% [markdown]
# ### Second Example

# %%
n_win_numb=256;
n_win = np.hamming(n_win_numb);
n_overlap = 128;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Comparison: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %% [markdown]
# ### Third Example

# %%
n_win_numb=8;
n_win = np.hamming(n_win_numb);
n_overlap = 0;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Comparison: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %% [markdown]
# ## Increasing winow length

# %%
n_win_numb = 32;
n_win = np.hamming(n_win_numb);
n_overlap = 16;
nfft = n_win_numb;

# %%
plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Length: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 128;
n_win = np.hamming(n_win_numb);
n_overlap = 16;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Length: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 256;
n_win = np.hamming(n_win_numb);
n_overlap = 16;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Length: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %% [markdown]
# ## Increasing Overlap

# %%
n_win_numb = 256;
n_win = np.hamming(n_win_numb);
n_overlap = 32;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 256;
n_win = np.hamming(n_win_numb);
n_overlap = 128;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 256;
n_win = np.hamming(n_win_numb);
n_overlap = 250;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %% [markdown]
# ## Increasing nfft

# %%
n_win_numb = 32;
n_win = np.hamming(n_win_numb);
n_overlap = 30;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 32;
n_win = np.hamming(n_win_numb);
n_overlap = 30;
nfft = n_win_numb;
pad_to = nfft*2;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap, pad_to=pad_to);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft, 'pad_to=',pad_to]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 32;
n_win = np.hamming(n_win_numb);
n_overlap = 30;
nfft = n_win_numb;
pad_to = nfft*10;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap, pad_to=pad_to);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft, 'pad_to=',pad_to]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %% [markdown]
# ## Comparison Study

# %%
n_win_numb = 32;
n_win = np.hamming(n_win_numb);
n_overlap = 0;
nfft = n_win_numb;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 128;
n_win = np.hamming(n_win_numb);
n_overlap = 127;
nfft = n_win_numb;
pad_to = nfft*10;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap, pad_to=pad_to);
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft, 'pad_to=',pad_to]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
n_win_numb = 128;
n_win = np.hamming(n_win_numb);
n_overlap = 127;
nfft = n_win_numb;
pad_to = nfft*10;

plt.figure(figsize=(8,6))
plt.specgram(y, NFFT = nfft, Fs = fs, window = n_win, noverlap = n_overlap, pad_to=pad_to, scale = 'linear');
plt.title(['Increasing Win Overlap: win=',n_win_numb,' / overlap=',n_overlap, ' / nfft=',nfft, 'pad_to=',pad_to]);
plt.xlabel('time(s)');plt.ylabel('freq(Hz)')
# Out:
# Text(0, 0.5, 'freq(Hz)')

# %%
# !pip install librosa
# Out:
# Collecting librosa
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (0.24.2)
# Requirement already satisfied: numba>=0.45.1 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (0.54.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (1.20.3)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3.cp26.cp27.cp32.cp33.cp34.cp35.cp36.pp27.pp32.pp33-none-win_amd64.whl (689 kB)
# Collecting pooch>=1.0
#   Downloading pooch-1.6.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: joblib>=0.14 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (1.1.0)
# Collecting audioread>=2.1.5
#   Downloading audioread-2.1.9.tar.gz (377 kB)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (21.0)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (1.7.1)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\billy\anaconda3\lib\site-packages (from librosa) (5.1.0)
# Requirement already satisfied: setuptools in c:\users\billy\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (58.0.4)
# Requirement already satisfied: llvmlite<0.38,>=0.37.0rc1 in c:\users\billy\anaconda3\lib\site-packages (from numba>=0.45.1->librosa) (0.37.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\billy\anaconda3\lib\site-packages (from packaging>=20.0->librosa) (3.0.4)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\billy\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in c:\users\billy\anaconda3\lib\site-packages (from pooch>=1.0->librosa) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\billy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\billy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\billy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\billy\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.7)
# Requirement already satisfied: six>=1.3 in c:\users\billy\anaconda3\lib\site-packages (from resampy>=0.2.2->librosa) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\billy\anaconda3\lib\site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\billy\anaconda3\lib\site-packages (from soundfile>=0.10.2->librosa) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\billy\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.20)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py): started
#   Building wheel for audioread (setup.py): finished with status 'done'
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23154 sha256=1b01ddd31c3d4bb982361239f09ee12afce49668d49ec4dbccdb32caff1af72c
#   Stored in directory: c:\users\billy\appdata\local\pip\cache\wheels\a2\a3\bd\ec1568ce7515115a11ab686d509ad302124c782af065de47ee
#   Building wheel for resampy (setup.py): started
#   Building wheel for resampy (setup.py): finished with status 'done'
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320731 sha256=2651a8d1d750e8d13eee43316accd62e2ca7fcf4609c32d56a00baefa6c428d4
#   Stored in directory: c:\users\billy\appdata\local\pip\cache\wheels\86\2c\7d\46a32a246b0e5939cea2c5ec1492164073e0c5d16d666ae2cd
# Successfully built audioread resampy
# Installing collected packages: soundfile, resampy, pooch, audioread, librosa
# Successfully installed audioread-2.1.9 librosa-0.9.1 pooch-1.6.0 resampy-0.2.2 soundfile-0.10.3.post1

# %%
import librosa
import librosa.display

# %%
S = librosa.feature.melspectrogram(y=y, sr=fs, S=None, n_fft=nfft, hop_length =n_overlap)
plt.figure(figsize=(8, 6))
S_dB = librosa.power_to_db(S, ref=np.max)
img = librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=fs)
# Out:
# C:\Users\billy\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   return f(*args, **kwargs)
